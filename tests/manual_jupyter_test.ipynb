# %% [markdown]
# # pLannotate API demo
#
# A quick manual check of the public `Construct` API. Requires the annotation databases (`plannotate setupdb`) and the `plot` extra.

# %%
from plannotate import Construct

seq = "..."

# annotate the sequence (detailed mode, linear construct)
construct = Construct(seq, linear=True, detailed=True)
construct.summary()

# %%
# pandas DataFrame of the annotations
construct.annotations_df

# %%
# annotated Biopython SeqRecord / GenBank text
print(construct.to_genbank())

# %%
# interactive plasmid map (renders inline in Jupyter)
construct.plot()
